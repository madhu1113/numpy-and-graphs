# %% [markdown]
# # Graphs

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Why do we use cufflings offline?
# There are 2 modes available i) online ii) offline
# whenever we are doing execution in our client machine it will be always offline.

# %% [markdown]
# # Analysis of iris dataset

# %%
#  inside sns there are some inbuilt data set like titanic dataset, iris dataset.
df = sns.load_dataset('iris')

# %%
# from the data set we can see that we have 4 numerical columnn and 1 catogrical column.
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# by default plot() gives line graph.
# graph is for numerical column. x axis- all the rows, y axis- values
df.plot()
# Out:
# <AxesSubplot:>

# %%
# we use alpha to have control on colours it's range is in between 0 to 1.
df.plot(kind = 'area', alpha = 0.6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # what is the range in which petal_width is fluctuating?

# %% [markdown]
# # Method 1

# %%
min(df.petal_width)
# Out:
# 0.1

# %%
max(df.petal_width)
# Out:
# 2.5

# %% [markdown]
# Petal_width is fluctuating between 0.1 to 2.5

# %% [markdown]
# # Method 2

# %% [markdown]
# From the graph approx we can say it lies b/w o.1 to 2.3 or 2.5 but we can't give the exact estimate.

# %% [markdown]
# # Out of this four numerical column(i.e sepal_length, sepal_width, petal_length, petal_width) which one has the maximum fluctuation?

# %% [markdown]
# From the graph we can say that petal_length has the maximum fluctuation.

# %%
# in area plot whatever o/p we have in line plot it just fills it with different colours.

df.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
# we use 'alpha' to have control on colours it's range is in between 0 to 1.
df.plot(kind = 'area', alpha = 0.6)
# Out:
# <AxesSubplot:>

# %%
# 'stacked = False' means it's scale has changed and it is stacked or overlap over one another.
df.plot(kind = 'area' , alpha = 0.6 , stacked = False  )
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Relation between 'sepal_length' and 'sepal_width'

# %%
# Here we are drawing scatter plot which means dot graph.
# from the graph we can say that data set is completely distributed and there is no relation.
df.plot.scatter(x ='sepal_length' , y ='sepal_width'  )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Relation between 'sepal_length' and 'petal_length'

# %%
# Here from this graph we can say that when sepal_length is increasing petal_length is also increasing.
df.plot.scatter(x ='sepal_length' , y ='petal_length'  )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # Relation between 'sepal_length' and 'sepal_width'

# %%
# 'c = 'sepal_width'' is a third parameter whose scale is given in the right side. whose range is in between 2.0 to 4.5 from lighter to darker colour.
# This 3rd parameter decides the colour of the dot in this particular graph.
df.plot.scatter(x ='sepal_length' , y ='petal_length' , c =  'sepal_width' )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# The 4th parameter 's = 100' means size of the dot we can increase and decrease the sixe accordingly.
df.plot.scatter(x ='sepal_length' , y ='petal_length' , c =  'sepal_width', s = 100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # How to make size of the dot(which is s) as a dynamic parameter.

# %%
# Here the size 's' varies with the 'sepal length' we can assign a constant value or a variable.
df.plot.scatter(x ='sepal_length' , y ='petal_length' , c =  'sepal_width', s = df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # Plot hexabin graph on iris dataset.

# %%
# In this case all the dots are represented in the form of hexabin. and we can control the grid size using 'gridsize' parameter.
df.plot.hexbin(x ='sepal_length' , y ='petal_length',gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# cmap="viridis" this means colour map which we use to choose any colour of our choice. which is optional. we use it to create a fancy graph.
df.plot.hexbin(x ='sepal_length' , y ='petal_length',gridsize=10,cmap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # 3d plot

# %%
# with the help of mplot3d we will be able to plot 3d graphs
from mpl_toolkits import mplot3d

# %% [markdown]
# # create data points for x-axis and y-axis and z-axis since it is 3d graph.

# %%
# we use linespace to generate evenly spaced numbers over a specified interval.
# It will generate the 30 evenly spaced data points b/w 1 to 6. 
x = np.linspace(-1,6 , 30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,6 , 30 )

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z = x+y

# %%
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %% [markdown]
# # plot a 3d graph

# %%
ax = plt.axes(projection = '3d') # here we are trying to create the axis(i.e the 3d enviornment(white colour grid enviornment) we are trying to create with the help of this)
ax.plot3D(x,y,z) # Here we are giving x,y and z coordinate. First it creates the dots then it creates line there.
ax.set_xlabel('x') # Here we just label the x axis lly we set y and z axis. so that it will show which one is x-axis and so on.
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Create a 3d graph for sepal_length,	sepal_width and	petal_length in iris dataset.

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Increase the size of window or canvas

# %%
# using figsize we can increase or decrease the canvas or window size by passing horizontal and vertical parameter.
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bar graph

# %%
# Since we are not able to understand the data so we can take a piece of data and try to plot it.
df.plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# Take a few rows and plot the graph. In this case we are choosing from 5 to 10th row.
df.iloc[5:11].plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
# kind = barh flips the graph horizontally.
df.iloc[5:11].plot(kind = 'barh', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogram graph

# %%
# Histogram which represents range on x-axis and frequency on y-axis i.e no. of data points in particular range..
# In the below graph how many data points are present between range 0 to 1? --> Ans 50 approx
# It is similar to value_count or group_by count operation
df.plot(kind = 'hist',figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Plot histogram for a particular column

# %%
# From the graph we can concluse that actual data inside 'sepal_length' lie b/w 3 to 7.8 approx.
# What is the range where majority of data points lie?--> approx 5.4 to 5.7
df['sepal_length'].plot(kind = 'hist', figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# when we call hist() function over a data frme it gives the histogram of all the numerical data.where 'alpha' is the density of color which lies between 0 to 1.
df.hist(figsize = (20,10), color = 'b', alpha = 0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# To choose a specific color go to this website 'https://uicolorpicker.com/' and choose one.
df.hist(figsize = (20,10), color = '#E6425E', alpha = 0.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# # Do the simliar kind of operations using cufflinks

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# iplot() gives interactive line graph.
df.iplot()
# Out:
# <div>                            <div id="bd7ae429-72db-47ec-baee-fd76035645f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # comparision graph using cufflinks

# %%
# Scatter plot of two columns .e 'sepal_length' and 'sepal_width'
df.iplot(x = 'sepal_length' , y = 'sepal_width',kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="055391e1-c17d-402e-b0e5-e9f96f9a3e4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Bubble plot in cufflings

# %%
# 2d bubble plot giving x and y axis.
df.iplot(x ='sepal_length' ,y ='sepal_width', size ='sepal_length' , kind = 'bubble')
# Out:
# <div>                            <div id="4da654d5-6a3e-473f-a895-83db44182d39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# 3d bubble graph by giving x,y and z axis
df.iplot(x ='sepal_length' ,y ='sepal_width' ,z ='petal_length'  ,size = 'sepal_length' ,kind = 'bubble3d')
# Out:
# <div>                            <div id="b562982a-3cf8-4da7-a7b0-e6202cff6908" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # load tips dataset using seaborn

# %%
# It is inbuilt dataset inside seaborn
# It is basically hotel data set and tip given by the customer.
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # find out the relationship between total_bill  and tip.
# # When bill size is increasing whether tip size is increasing or not??

# %%
# Ans:- From the graph we can say Yes. we can see that highest tip is given by the highest paid customer.
df1.plot(x='total_bill',y='tip',kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Draw the same graph using iplot

# %%
# Here can get the exact value means the maximum tip given is 10 by the ustomer whose total bill was $50.81.
df1.iplot(x = 'total_bill', y = 'tip', kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="62f9a48e-22f4-489f-b536-774c9ab0f867" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Plot the same graph using seaborn

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 )

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Find the no. of smoker and non smoker customer

# %%
# From the data we can see that non smaoker are 151 and smoker are 93
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# # How to get smoker and non smoker count through graph

# %%
# hue argument catogrize it into different catof=gries in this case it is smoker and non-smoker.
# person who gave the highest tip was a smoker or non smoker?--> Smoker
sns.relplot(x = 'total_bill', y = 'tip' , data = df1, hue = 'smoker' )

# %%
# hue catogrise the data based on the different types of items inside the column based on colour of data points.. In case of time only two types are there i.r lunch and dinner time.
# Q.) Highest tip is given at what time?--> Dinner time
sns.relplot(x = 'total_bill', y = 'tip' , data = df1, hue = 'time' )

# %%
# From this graph we can conclude that Person who gave the highest tip  person was non-smoker and came for dinner.
# style is just a parameter which does grouping operation based on style of data points.
sns.relplot(x = 'total_bill', y = 'tip' , data = df1, hue = 'time', style = 'smoker' )

# %% [markdown]
# # Person who gave the highest tip was a male or a female?

# %%
# From graph we can conclude that it was a male.
sns.relplot(x = 'total_bill', y = 'tip' , data = df1, hue = 'time', style = 'sex' )

# %%
# In this case it does both styling and colouring for all the sizes
# Hence from graph we can conclude that people who gave the highest tip was total 3 person in a group.
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 , hue = 'size',style = 'size' )

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Seperate the data

# %% [markdown]
# # Plot the graph for people who came for lunch and for dinner seperately

# %%
# col = 'time' It seperates the graph in different catogry in that particular column as here we have only two catogry i.e Lunch and dinner time.
# From the graph we can conclude that more people are coming for dinner than lunch.
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 ,col ='time' )

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Draw the different scatter graph for "iris" data. catogrise it based in "species".

# %%
# Since we have three catogry of species i.e setosa, cersicolor and virginica. Hence we got three graphs here.
sns.relplot(x = 'sepal_length', y = 'sepal_width', data = df, col = 'species' )

# %% [markdown]
# # Create different graph based on "day" in "tip" dataset

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Which days most of the people are visiting?

# %%
# Since inside day column we have 4 catogries i.e "Thru", "Fri", "Sat", "sun". Hence we got 4 different graphs.
# From the graph we can concluse that most of the people are coming on "sat" and "sun".
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 ,col ='day' )

# %% [markdown]
# # catplot graph
# # Catogrical plot

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Which day we have highest bill amount??

# %%
# Here on x axis we should have catogrical data.
# From graph we can conclude that highest bill was paid on "sat".
sns.catplot(x = 'day' , y = 'total_bill',data= df1)

# %%
# Another example of catplot.
sns.catplot(x = 'time' , y = 'total_bill',data= df1)

# %% [markdown]
# # pairplot Graph

# %%
# Here we get the graph only for numerical data
sns.pairplot(df1)

# %% [markdown]
# # Pairplot for iris dataset

# %%
# In diagonal we get the histogram of the respective column.
# This graph gives the combination of all vs all
sns.pairplot(df)

# %% [markdown]
# # same thing we can do using plotly cufflinks which is inrteractive graphs

# %%
# we can get the same o/p of pairplot using scatter_matrix(). This function is inside cufflings. Which gives interactive graphs.
df.scatter_matrix()
# Out:
# <div>                            <div id="4c10dfd3-a8f2-4e3f-9bdb-b010e5e6c7e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # From matplotlib plots documentation

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %% [markdown]
# # Change the code for 'iris' data

# %%
# Here we get the histogram for sepal_length
import matplotlib.pyplot as plt
import numpy as np


# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(df['sepal_length'], bins=8, linewidth=0.9, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# # Animation line graph from matplotlib documentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=True, save_count=50)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()

# %% [markdown]
# # jointplot using seaborn on tip data set

# %%
# It gives both scatter plot and histogram. As  we can see on graph it plots 2 histogram one for x-axis and one for y-axis.
sns.jointplot(x =df1.total_bill , y = df1.tip )

# %% [markdown]
# # Draw the same graph using hexagon

# %%
sns.jointplot(x =df1.total_bill , y = df1.tip,kind = 'hex' )

# %% [markdown]
# # pairplot in seabon

# %%
sns.pairplot(df1)

# %% [markdown]
# # Regression plot in seaborn

# %%
# It uses the ml algo in backend and draw the best fit line.
sns.regplot(x = df1.total_bill , y = df1.tip)
sns.set(rc={'figure.figsize':(20,10)}) # To change the figure size

# %% [markdown]
# # seaborn documentation example

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="country",xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
sns.load_dataset("car_crashes")
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # examples from plotly express for tips dataset.

# %%
import plotly.express as px

fig = px.scatter(df1, x="total_bill", y="tip", color="time")
fig.show()
# Out:
# <div>                            <div id="32b3577e-4120-444b-bdb6-91acb9710d11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32b3577e-4120-444b-bdb6-91acb9710d11")) {                    Plotly.newPlot(                        "32b3577e-4120-444b-bdb6-91acb9710d11",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %% [markdown]
# # bar plot from plotly

# %%
import plotly.express as px

fig = px.bar(df1, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()
# Out:
# <div>                            <div id="02325e7a-b224-44c5-a6a0-f4c4be1a8f7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02325e7a-b224-44c5-a6a0-f4c4be1a8f7c")) {                    Plotly.newPlot(                        "02325e7a-b224-44c5-a6a0-f4c4be1a8f7c",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %%
# According to current situation better to learn cufflings and plotly. even cufflings is more than enogh so better just learn this only.

# %%
# cufflinks - https://github.com/santosjorge/cufflinks
# plotly - https://plotly.com/python/plotly-express/
# seaborn - https://seaborn.pydata.org/index.html
# matplotlib - https://matplotlib.org/stable/index.html
